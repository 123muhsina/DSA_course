# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1.Read the dataset to python environment.

data=pd.read_excel('/content/iris.xls')

# %%
# to display data
data

# %%
# 2. Display the columns in the dataset.
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#(for analysis purpose)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#(for analysis purpose)
data.describe()

# %%
# 3.Calculate the mean of each column of the dataset.
data.mean()
# Out:
# <ipython-input-22-76a15efdff3e>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
# 4. Check for the null values present in the dataset.

data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
# 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

#BAR CHART

plt.bar(data['Classification'],data['SL'],color="red", width =0.4)
plt.title('Classification vs SL')
plt.xlabel("Classification")
plt.ylabel("SL")
plt.show()

# %%
# LINE CHART

plt.plot(data['SL'],data['PW'])
plt.title("LINE CHART (SL vs PW)")
# Out:
# Text(0.5, 1.0, 'LINE CHART (SL vs PW)')

# %%
# SCATTER PLOT

plt.scatter(data['SL'], data['PL'], c='green')
plt.title("SCATTER CHART (SL vs PL)")
# Out:
# Text(0.5, 1.0, 'SCATTER CHART (SL vs PL)')
